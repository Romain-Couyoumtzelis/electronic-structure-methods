# %% [markdown]
# # Potential Energy Scans and Visualisation of Trajectories
#
#
# The range of problems that can be tackled with Psi4 or other electronic structure packages is not limited
# to wavefunction or geometry optimisations. We can use python to create complex inputs, adjusting various settings, or making specific modifications of
# some variables.
#
#
# In this set of exercises, you will instruct Psi4 to
# selectively scan one degree of freedom of a potential energy surface.

# %% [markdown]
# ## Scanning a Potential Energy Surface: Dihedral Scan of Butane
#
#
# Potential energy surfaces (PES) are complex objects which are, in
# general, 3N-6 dimensional, where N is the number of atoms. Therefore, obtaining the complete topology of
# a PES is not feasible for most molecules. However, one may limit the
# sampling of the surface to a few degrees of freedom that are of interest
# and relevant to the problem under exa
# mination (*cf.* figure 1). Scans
# along limited degrees of freedom may be helpful if one needs information
# about various possible (local) minima, for example if (or whether) one
# is trapped in one of them. In practice, the degrees of freedom can be
# defined by a Z-matrix, such as the one that you have already been using
# in the previous exercises.
#
#
#
# ```{figure} ../../images/pesslize.jpg
# ---
# name: PES
# ---
# Example of a 2D PES (right) and a 1D potential energy profile (left)
# obtained by considering only one degree of freedom.
# ```
#
#
#
# In a *relaxed PES scan*, all degrees of freedom that are not under
# consideration are optimised, and one obtains a minimum energy path along
# the chosen degree(s) of freedom. This implies that a constrained
# optimisation is carried out for each desired value of the degree of
# freedom that is being sampled.
# Instead, one may freeze the remaining degrees of
# freedom, keeping them fixed at their initial values, lowering the computational cost. This procedure is
# referred to as a *rigid PES scan*. For simple scans of bond angles or
# lengths in a pre-optimised structure, this is often sufficient (and more
# efficient).
#
# In this exercise, you will perform a relaxed potential energy
# scan of the dihedral in butane in order to determine the possible
# configurational minima, and the rotational barrier.

# %%
import psi4
import py3Dmol

import numpy as np

import matplotlib.pyplot as plt

# %%
psi4.set_num_threads(2)
psi4.set_memory('2 GB')
# Out:
#   Threads set to 2 by Python driver.
# 2000000000
#   Memory set to   1.863 GiB by Python driver.

# %%
import sys
sys.path.append("..")
from helpers import *

# %% [markdown]
# ### Starting geometry

# %%
butane = psi4.geometry("""
C       
C    1    1.450000
C    1    1.450000      2  109.471000
H    1 1.089         2 109.471000         3 120
H    1 1.089        2 109.471000          3 -120
C    2 1.45         1 109.471000         3 180
H    2 1.089        1 109.471000        6 120
H    2 1.089         1 109.471000          6 240
H    3 1.089         1 109.471000          2 180
H    3 1.089        1 109.471000         9 120
H    3 1.089        1 109.471000         9 240
H    6 1.089        2 109.471000         1 180
H    6 1.089       2 109.471000        12 120
H    6 1.089        2 109.471000        12 240
""")

# %%
drawXYZ_labeled(butane)
# Out:
# <div id="3dmolviewer_17652817052206306"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17652817052206306" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17652817052206306 = null;
# var warn = document.getElementById("3dmolwarning_17652817052206306");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17652817052206306 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17652817052206306"),{backgroundColor:"white"});
# viewer_17652817052206306.zoomTo();
# 	viewer_17652817052206306.addModel("14\n\n C    0.000000000000    0.725000000000    0.000000000000\n C    0.000000000000   -0.725000000000    0.000000000000\n C   -1.367074971503    1.208328069007    0.000000000000\n H    0.513360222058    1.087996046309    0.889165987188\n H    0.513360222058    1.087996046309   -0.889165987188\n C    1.367074971503   -1.208328069007    0.000000000000\n H   -0.513360222058   -1.087996046309    0.889165987188\n H   -0.513360222058   -1.087996046309   -0.889165987188\n H   -1.367074971503    2.297328069007    0.000000000000\n H   -1.880429602190    0.845324115338   -0.889165987188\n H   -1.880429602190    0.845324115338    0.889165987188\n H    1.367074971503   -2.297328069007    0.000000000000\n H    1.880429602190   -0.845324115338   -0.889165987188\n H    1.880429602190   -0.845324115338    0.889165987188\n","xyz");
# 	viewer_17652817052206306.addLabel("0",{"position": {"x": 0.0, "y": 0.7250000000016578, "z": 0.0}, "inFront": true});
# 	viewer_17652817052206306.addLabel("1",{"position": {"x": 0.0, "y": -0.7250000000016578, "z": 0.0}, "inFront": true});
# 	viewer_17652817052206306.addLabel("2",{"position": {"x": -1.367074971506163, "y": 1.2083280690096954, "z": 0.0}, "inFront": true});
# 	viewer_17652817052206306.addLabel("3",{"position": {"x": 0.5133602220586935, "y": 1.087996046311832, "z": 0.8891659871904984}, "inFront": true});
# 	viewer_17652817052206306.addLabel("4",{"position": {"x": 0.5133602220586935, "y": 1.087996046311832, "z": -0.8891659871904984}, "inFront": true});
# 	viewer_17652817052206306.addLabel("5",{"position": {"x": 1.367074971506163, "y": -1.2083280690096956, "z": 0.0}, "inFront": true});
# 	viewer_17652817052206306.addLabel("6",{"position": {"x": -0.5133602220586935, "y": -1.087996046311832, "z": 0.8891659871904984}, "inFront": true});
# 	viewer_17652817052206306.addLabel("7",{"position": {"x": -0.5133602220586935, "y": -1.087996046311832, "z": -0.8891659871904984}, "inFront": true});
# 	viewer_17652817052206306.addLabel("8",{"position": {"x": -1.367074971506163, "y": 2.2973280690121856, "z": 0.0}, "inFront": true});
# 	viewer_17652817052206306.addLabel("9",{"position": {"x": -1.8804296021942979, "y": 0.8453241153397411, "z": -0.8891659871904983}, "inFront": true});
# 	viewer_17652817052206306.addLabel("10",{"position": {"x": -1.8804296021942979, "y": 0.845324115339741, "z": 0.8891659871904984}, "inFront": true});
# 	viewer_17652817052206306.addLabel("11",{"position": {"x": 1.367074971506163, "y": -2.2973280690121856, "z": 0.0}, "inFront": true});
# 	viewer_17652817052206306.addLabel("12",{"position": {"x": 1.8804296021942979, "y": -0.8453241153397411, "z": -0.8891659871904984}, "inFront": true});
# 	viewer_17652817052206306.addLabel("13",{"position": {"x": 1.8804296021942979, "y": -0.845324115339741, "z": 0.8891659871904983}, "inFront": true});
# 	viewer_17652817052206306.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17652817052206306.setStyle({"model": 0},{"stick": {"colorscheme": "yellowCarbon"}, "sphere": {"scale": 0.1}});
# 	viewer_17652817052206306.zoomTo();
# viewer_17652817052206306.render();
# });
# </script>

# %%
drawXYZ(butane)
# Out:
# <div id="3dmolviewer_17652817056567857"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17652817056567857" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17652817056567857 = null;
# var warn = document.getElementById("3dmolwarning_17652817056567857");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17652817056567857 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17652817056567857"),{backgroundColor:"white"});
# viewer_17652817056567857.zoomTo();
# 	viewer_17652817056567857.addModel("14\n\n C    0.000000000000    0.725000000000    0.000000000000\n C    0.000000000000   -0.725000000000    0.000000000000\n C   -1.367074971503    1.208328069007    0.000000000000\n H    0.513360222058    1.087996046309    0.889165987188\n H    0.513360222058    1.087996046309   -0.889165987188\n C    1.367074971503   -1.208328069007    0.000000000000\n H   -0.513360222058   -1.087996046309    0.889165987188\n H   -0.513360222058   -1.087996046309   -0.889165987188\n H   -1.367074971503    2.297328069007    0.000000000000\n H   -1.880429602190    0.845324115338   -0.889165987188\n H   -1.880429602190    0.845324115338    0.889165987188\n H    1.367074971503   -2.297328069007    0.000000000000\n H    1.880429602190   -0.845324115338   -0.889165987188\n H    1.880429602190   -0.845324115338    0.889165987188\n","xyz");
# 	viewer_17652817056567857.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17652817056567857.zoomTo();
# viewer_17652817056567857.render();
# });
# </script>

# %% [markdown]
# ### PES scan

# %% [markdown]
# Now that we had a look at the butane molecule, let's perform the rigid PES scan. We will fix the dihedral angle at different values and do single point ca
# lculations.
# First, we need to optimize the the geometry provided above.

# %%
psi4.core.clean_options()
psi4.core.clean()

psi4.core.clean_variables()

# %%
psi4.core.clean_options()
psi4.core.clean()
psi4.core.clean_variables()

# Rediriger tout le output détaillé de Psi4 vers un fichier, pas dans le notebook
psi4.core.set_output_file('butane_opt.log', False)  # False = écraser, pas append


# Optimisation simple
E_opt = psi4.optimize("blyp/6-31+G*", molecule=butane)

# Dans le notebook, tu ne vois que ça :
print("Énergie optimisée (hartree) :", E_opt)
# Out:
# Optimizer: Optimization complete!
# Énergie optimisée (hartree) : -158.3424170714377

# %%
dihedrals = np.linspace(180,-180, 37) #We set here the dihedrals that we are going to use for the scan
PES = {} #Here we will store the optimized energy for each dihedral. This is a dictionary
geometries = [] #Here we will store the optimized geometries. This is a list

# %%
butane.print_in_input_format()

# %% [markdown]
# The geometry optimization will print you the optimized coordinates in the format you provided them at the end if you call `butane.print_in_input_for
# mat()`. Here, this is the z-matrix format. Use these coordinates below and create a python f-string where you replace the dihedral that we want to scan with a variable.
#
# Save the molecules in the `geometries` list (
# use `butane.clone()`) and save the calculated energies in the `PES` dictionary.

# %%
geom_template = """
C
C             1    1.547000

C             1    1.544805      2  113.485996
H             1    1.107750      2  109.114039      3  122.235068
H             1    1.107750      2  109.114039      3 -122.235068
C             2    1.544805      1  113.485996      3 {phi}
H             2    1.107750      1  109.114039      6  122.235068
H             2    1.107750      1  109.114039      6 -122.235068
H             3    1.104530      1  111.405568      2 -180.000000
H             3    1.105476      1  111.259684      9  120.080375
H             3    1.105476      1  111.259684      9 -120.080375

H             6    1.104530      2  111.405568      1 -180.000000
H             6    1.105476      2  111.259684     12  120.080375
H             6    1.105476      2  111.259684     12 -120.080375
"""

# %%
psi4.core.set_output_file('output.dat', False)  # pour ne pas polluer le notebook

for phi in dihedrals:
    print(f"dihedral = {phi}°")
    
    # Construire la géométrie avec ce dièdre
    geom_str = geom_template.format(phi=phi)
    butane_phi = psi4.geometry(geom_str)
    
    # Calcul d'énergie (même méthode et base que pour l'optimisation)
    E = psi4.energy("blyp/6-31+G*", molecule=butane_phi)
    
    # Stocker l'énergie dans le dictionnaire PES
    PES[phi] = E
    
    # Stocker la géométrie dans la liste geometries
    geometries.append(butane_phi.clone())
# Out:
# dihedral = 180.0°
# dihedral = 170.0°
# dihedral = 160.0°
# dihedral = 150.0°
# dihedral = 140.0°
# dihedral = 130.0°
# dihedral = 120.0°
# dihedral = 110.0°
# dihedral = 100.0°
# dihedral = 90.0°
# dihedral = 80.0°
# dihedral = 70.0°
# dihedral = 60.0°
# dihedral = 50.0°
# dihedral = 40.0°
# dihedral = 30.0°
# dihedral = 20.0°
# dihedral = 10.0°
# dihedral = 0.0°
# dihedral = -10.0°
# dihedral = -20.0°
# dihedral = -30.0°
# dihedral = -40.0°
# dihedral = -50.0°
# dihedral = -60.0°
# dihedral = -70.0°
# dihedral = -80.0°
# dihedral = -90.0°
# dihedral = -100.0°
# dihedral = -110.0°
# dihedral = -120.0°
# dihedral = -130.0°
# dihedral = -140.0°
# dihedral = -150.0°
# dihedral = -160.0°
# dihedral = -170.0°
# dihedral = -180.0°

# %%
# Do something HERE 
#for dihedral in dihedrals:
#    print(f"optimizing {dihedral}")
#    butane = psi4.geometry(f"""  #you get this geometry from the print_in_input_format() command
#    x i bond k angle j {dihedral} #this is the dihedral we want to optimize
#    x i bond k angle j dihedral
#    """)
#    E = .... # the energy should be calculated using the same method and basis set above
#    PES[dihedral] =  set to energy just calculated
#    geometries.append( insert clone of molecule here   )

# %%
# Convert the energy units to kcal/mol
# you can use psi4.constants.hartree2kcalmol for the unit conversion 
# in python you can use list comprehensions e.g [x+1 for x in lst] will increase every value in lst by 1.
# to access the values in the dictionary PES you can use PES.values() which return a list.
# to construct the list comprehensions set energies equal to... .
# [e*conversionfactor for e in list(insert the call to the list of PES values here)].
energies = [e*psi4.constants.hartree2kcalmol for e in PES.values()]


#Rescale the energy scale by setting the minimum value as the zero of the scale
#and change everything accordingly
# the function np.min(lst) returns the lowest value of a list. 
# to use broadcasting you need to convert the list into a np.array by calling np.array(energies)
energies = np.array(energies)
e_min = np.min(energies)
energies = energies - e_min

# %% [markdown]
# For relaxed scans you can use such a input structure. However, in the interest of time we perform a rigid scan here.
#
# ``` python
# for dihedral in dihedrals:
#
#     psi4.set_options({
#         "fixed_dihedral": f"4 2 1 3 {dihedral}", #This option specifies the dihedral angles between atoms to be fixed
#     })
#     E = psi4.optimize('blyp/6-31+G*', molecule=butane)
# ```

# %% [markdown]
# ### Visualization of the Results

# %% [markdown]
# Now, let’s plot the PES at the different dihedral considered. You can use a little helper function which will read in the optimized geometries just calculated and the dihedrals and return the PES and the corresponding geometry at each dihedral value.

# %%
# ============================================================
# Analyse du scan : slider, profil d'énergie, minima / maxima
# ============================================================

# 1) Construire les trajectoires pour le slider 3D
traj = [geom.save_string_xyz_file() for geom in geometries]
traj_arrays = [geom.to_arrays()[0] for geom in geometries]

# Slider interactif : géométrie + énergie vs dièdre
drawXYZGeomSliderMolecularProperty(traj, dihedrals, energies, 'dihedral')
# (Les dihedral doivent être des entiers, ce qui est le cas avec np.linspace(180, -180, 37))

# 2) Tracer le profil d'énergie (PES 1D)
fig, ax = plt.subplots(1)
ax.plot(dihedrals, energies, marker='o')
ax.set_xlabel('dihedral [deg]')
ax.set_ylabel('E - E_min [kcal/mol]')
plt.show()

# 3) Trouver les minima et maxima locaux
E = np.array(energies)
phi = np.array(dihedrals, dtype=float)

min_indices = []
max_indices = []

for i in range(1, len(E) - 1):
    if E[i] < E[i-1] and E[i] < E[i+1]:
        min_indices.append(i)
    if E[i] > E[i-1] and E[i] > E[i+1]:
        max_indices.append(i)

print("=== Minima locaux ===")
for i in min_indices:
    print(f"  dihedral = {phi[i]:6.1f}°, E = {E[i]:5.2f} kcal/mol")

print("\n=== Maxima locaux ===")
for i in max_indices:
    print(f"  dihedral = {phi[i]:6.1f}°, E = {E[i]:5.2f} kcal/mol")

# 4) Visualiser les conformations correspondantes
#    (tu peux exécuter ces blocs un par un pour regarder les structures)

print("\nAffichage des minima (conformations anti / gauche...)")
for i in min_indices:
    print(f"\nMinimum à φ = {phi[i]:.1f}°")
    drawXYZ(geometries[i])

print("\nAffichage des maxima (conformations éclipsées...)")
for i in max_indices:
    print(f"\nMaximum à φ = {phi[i]:.1f}°")
    drawXYZ(geometries[i])
# Out:
# interactive(children=(IntSlider(value=0, description='quantity', max=180, min=-180, step=10), Output()), _dom_…
# === Minima locaux ===
#   dihedral =   70.0°, E =  1.12 kcal/mol
#   dihedral =  -70.0°, E =  1.12 kcal/mol
#
# === Maxima locaux ===
#   dihedral =  120.0°, E =  3.36 kcal/mol
#   dihedral =    0.0°, E =  7.77 kcal/mol
#   dihedral = -120.0°, E =  3.36 kcal/mol
#
# Affichage des minima (conformations anti / gauche...)
#
# Minimum à φ = 70.0°
# <div id="3dmolviewer_17652819971405575"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17652819971405575" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17652819971405575 = null;
# var warn = document.getElementById("3dmolwarning_17652819971405575");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17652819971405575 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17652819971405575"),{backgroundColor:"white"});
# viewer_17652819971405575.zoomTo();
# 	viewer_17652819971405575.addModel("14\n\n C    0.000000000000   -0.773500000000   -0.600159448515\n C    0.000000000000    0.773500000000   -0.600159448515\n C   -0.812660017558   -1.389143278143    0.560439335719\n H   -0.405013517646   -1.136232102690   -1.565301683993\n H    1.045459818041   -1.136232102690   -0.549669320373\n C    0.812660017558    1.389143278143    0.560439335719\n H    0.405013517646    1.136232102690   -1.565301683993\n H   -1.045459818041    1.136232102690   -0.549669320373\n H   -0.789661309556   -2.492945230300    0.527593776729\n H   -0.411291659322   -1.075292536048    1.541499139843\n H   -1.871830739454   -1.075292536048    0.518818666085\n H    0.789661309556    2.492945230300    0.527593776729\n H    0.411291659322    1.075292536048    1.541499139843\n H    1.871830739454    1.075292536048    0.518818666085\n","xyz");
# 	viewer_17652819971405575.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17652819971405575.zoomTo();
# viewer_17652819971405575.render();
# });
# </script>
# Minimum à φ = -70.0°
# <div id="3dmolviewer_17652819971414433"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17652819971414433" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17652819971414433 = null;
# var warn = document.getElementById("3dmolwarning_17652819971414433");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17652819971414433 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17652819971414433"),{backgroundColor:"white"});
# viewer_17652819971414433.zoomTo();
# 	viewer_17652819971414433.addModel("14\n\n C    0.000000000000   -0.773500000000   -0.600159448515\n C    0.000000000000    0.773500000000   -0.600159448515\n C    0.812660017558   -1.389143278143    0.560439335719\n H   -1.045459818041   -1.136232102690   -0.549669320373\n H    0.405013517646   -1.136232102690   -1.565301683993\n C   -0.812660017558    1.389143278143    0.560439335719\n H    1.045459818041    1.136232102690   -0.549669320373\n H   -0.405013517646    1.136232102690   -1.565301683993\n H    0.789661309556   -2.492945230300    0.527593776729\n H    1.871830739454   -1.075292536048    0.518818666085\n H    0.411291659322   -1.075292536048    1.541499139843\n H   -0.789661309556    2.492945230300    0.527593776729\n H   -1.871830739454    1.075292536048    0.518818666085\n H   -0.411291659322    1.075292536048    1.541499139843\n","xyz");
# 	viewer_17652819971414433.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17652819971414433.zoomTo();
# viewer_17652819971414433.render();
# });
# </script>
# Affichage des maxima (conformations éclipsées...)
#
# Maximum à φ = 120.0°
# <div id="3dmolviewer_17652819971422644"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17652819971422644" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17652819971422644 = null;
# var warn = document.getElementById("3dmolwarning_17652819971422644");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17652819971422644 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17652819971422644"),{backgroundColor:"white"});
# viewer_17652819971422644.zoomTo();
# 	viewer_17652819971422644.addModel("14\n\n C    0.000000000000    0.773500000000    0.366329701976\n C    0.000000000000   -0.773500000000    0.366329701976\n C   -1.227010342897    1.389143278143   -0.342085049794\n H    0.040819828993    1.136232102690    1.412211734396\n H    0.926170323934    1.136232102690   -0.121260305348\n C    1.227010342897   -1.389143278143   -0.342085049794\n H   -0.040819828993   -1.136232102690    1.412211734396\n H   -0.926170323934   -1.136232102690   -0.121260305348\n H   -1.192285301698    2.492945230300   -0.322036537910\n H   -1.277860863441    1.075292536048   -1.400852787696\n H   -2.169355360900    1.075292536048    0.143260976571\n H    1.192285301698   -2.492945230300   -0.322036537910\n H    1.277860863441   -1.075292536048   -1.400852787696\n H    2.169355360900   -1.075292536048    0.143260976571\n","xyz");
# 	viewer_17652819971422644.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17652819971422644.zoomTo();
# viewer_17652819971422644.render();
# });
# </script>
# Maximum à φ = 0.0°
# <div id="3dmolviewer_17652819971430042"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17652819971430042" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17652819971430042 = null;
# var warn = document.getElementById("3dmolwarning_17652819971430042");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17652819971430042 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17652819971430042"),{backgroundColor:"white"});
# viewer_17652819971430042.zoomTo();
# 	viewer_17652819971430042.addModel("14\n\n C    0.000000000000    0.773500000000   -0.732659403953\n C    0.000000000000   -0.773500000000   -0.732659403953\n C    0.000000000000    1.389143278143    0.684170099588\n H    0.885350494941    1.136232102690   -1.290951429048\n H   -0.885350494941    1.136232102690   -1.290951429048\n C    0.000000000000   -1.389143278143    0.684170099588\n H   -0.885350494941   -1.136232102690   -1.290951429048\n H    0.885350494941   -1.136232102690   -1.290951429048\n H    0.000000000000    2.492945230300    0.644073075820\n H   -0.891494497459    1.075292536048    1.257591811125\n H    0.891494497459    1.075292536048    1.257591811125\n H    0.000000000000   -2.492945230300    0.644073075820\n H    0.891494497459   -1.075292536048    1.257591811125\n H   -0.891494497459   -1.075292536048    1.257591811125\n","xyz");
# 	viewer_17652819971430042.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17652819971430042.zoomTo();
# viewer_17652819971430042.render();
# });
# </script>
# Maximum à φ = -120.0°
# <div id="3dmolviewer_17652819971438458"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17652819971438458" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17652819971438458 = null;
# var warn = document.getElementById("3dmolwarning_17652819971438458");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17652819971438458 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17652819971438458"),{backgroundColor:"white"});
# viewer_17652819971438458.zoomTo();
# 	viewer_17652819971438458.addModel("14\n\n C    0.000000000000    0.773500000000   -0.366329701976\n C    0.000000000000   -0.773500000000   -0.366329701976\n C   -1.227010342897    1.389143278143    0.342085049794\n H    0.926170323934    1.136232102690    0.121260305348\n H    0.040819828993    1.136232102690   -1.412211734396\n C    1.227010342897   -1.389143278143    0.342085049794\n H   -0.926170323934   -1.136232102690    0.121260305348\n H   -0.040819828993   -1.136232102690   -1.412211734396\n H   -1.192285301698    2.492945230300    0.322036537910\n H   -2.169355360900    1.075292536048   -0.143260976571\n H   -1.277860863441    1.075292536048    1.400852787696\n H    1.192285301698   -2.492945230300    0.322036537910\n H    2.169355360900   -1.075292536048   -0.143260976571\n H    1.277860863441   -1.075292536048    1.400852787696\n","xyz");
# 	viewer_17652819971438458.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17652819971438458.zoomTo();
# viewer_17652819971438458.render();
# });
# </script>

# %%
traj = [geom.save_string_xyz_file() for geom in geometries]
traj_arrays = [geom.to_arrays()[0] for geom in geometries]


drawXYZGeomSliderMolecularProperty(traj, dihedrals, energies, 'dihedral')
# for the slider to function properly you must have dihedral angles of exact integers. 
# If that is not the case, adjust the number of dihedrals to divide -180 to 180 degrees into even steps (including the zero value).
# Out:
# interactive(children=(IntSlider(value=0, description='quantity', max=180, min=-180, step=10), Output()), _dom_…

# %% [markdown]
# Now, we can monitor different quantities during the rigid PES scan, to understand how the different dihedrals affect the overall geometry. One example is the bond length between C atoms 1 and 2, the central atoms of the dihedral for which we performed the scan. Having a look at the fluctuations
# of this bond legth during the scan can be easily done using one of the helper functions, which will read the coordinates of the two atoms and calculate their distance.

# %%
barrier = np.max(energies)   # en kcal/mol
phi_max = dihedrals[np.argmax(energies)]  # angle du max (≈ 0°)
print(barrier, phi_max)
# Out:
# 7.768976939114509 0.0

# %%
bond_length = []


for geom in traj_arrays:
    bond_length.append(calculate_bond(geom[0], geom[1])) #Here the bond length is calculated and saved in the list

# %%
fig, ax = plt.subplots(1)
ax.plot(dihedrals, bond_length)
ax.set_xlabel('dihedral')
ax.set_ylabel('bond [A]')
plt.show()

# %%
fig, ax = plt.subplots(1)
ax.plot(dihedrals, bond_length)
ax.set_xlabel('dihedral')
ax.set_ylabel('bond [A]')
plt.show()

# %% [markdown]
# ```{admonition} Exercise 1
# :class: exercise
# Does the bond length of the $H_3CH_2C-CH_2CH_3$ bond fluctuate as
#     the dihedral is changed? Why (not)?
#
# ```

# %% [markdown]
# ```{admonition} Exercise 2
# :class: exercise
# Create a potential energy profile along the dihedral by plotting the
#     energies of the system as a function of the scanned dihedral angle as done above.
#     Then, to each maximum and minimum, assign the corresponding
#     conformation from your trajectory. Show these conformations in your
#     report.
#     Assign also names to the conformations according to the *Newman
#     projections* you know from organic chemistry (where possible).
#
# ```

# %% [markdown]
# ```{admonition} Exercise 3
# :class: exercise
# The rotational barrier of butane lies between 5 and 6 kcal
#     mol$^{-1}$ [^Murcko1996]. Compare this value with the one you calculated and explain possible sources of error, leading to higher or lower barriers.
# ```
# [^Murcko1996] : Murcko M. A., Castejon H., Wiberg K.B., J. Phys. Chem., 1996, 100, 16162
