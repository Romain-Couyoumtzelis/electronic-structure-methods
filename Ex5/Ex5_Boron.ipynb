# %% [markdown]
# ## Recovering Correlation Energy: B atom

# %% [markdown]
# :::{panels}
# :column: col-12
# Based on **Basis sets**
#  Tricia D. Shepherd [![Orcid](../../images/orcid.png)](https://orcid.org/0000-0001-6512-8951), Ryan C. Fortenberry, Matthewy Kennedy, C. David Sheril, 2008-2019, The Psi4Education Developers &nbsp;&nbsp; License BSD-3
# :::

# %% [markdown]
# At the Hartree Fock level of theory, each electron experiences an average potential field of all the other electrons. In essence, it is a "mean field" approach that neglects individual electron-electron interactions or "electron correlation". Thus, we define the difference between the self-consistent field energy and the exact energy as the correlation energy. Two fundamentally different approaches to account for electron correlation effects are available by selecting a Correlation method: Moller Plesset (MP) Perturbation theory and Coupled Cluster (CC) theory.

# %% [markdown]
# :::{admonition} Exercise 1
# :class: exercise
#
# * Calculate the HF energy for Boron using the 6-311+G** basis set, then determine the value of the correlation energy for boron assuming an "experimental" energy of -24.608 Hartrees ([Schaefer III, Henry F., and Frank E. Harris. "Electronic Structure of Atomic Boron." Physical Review 167.1 (1968): 67](https://journals.aps.org/pr/abstract/10.1103/PhysRev.167.67)).
# * Using the same basis set, perform an energy calculation with CISD and full CI.
# * Using the same basis set, perform an energy calculation with MP2, MP3 and MP5.
# * Using the same basis set, perform an energy calculation with CCSD and CCSD(T).
#
# Determine the percentage of the correlation energy recovered for HF, MP2, MP5, CCSD, CCSD(T).
#
# Compare the performances of the different methods. In particular, you will see that some of the methods seem to overestimate the correlation recovered. How is it possible? (*Hint:* Think both about the theoretical aspects of the methods and *how* we are computing the recovered correlation energy).
# :::

# %% [markdown]
# :::{admonition} CCSD energy/mp2 energy
# :class: tip
# You may recover the CCSD energy from the CCSD(T) calculation, but you will have to look at the output file or by calculating both. In any case, the calculations for a single atom are quick.
#
# The same is true for the MP2 energy which can be extracted from the MP5 calculation.
# MP5 will require the use of the following options: `psi4.set_options({"reference" :"rohf", "qc_module":"detci"})` as Psi4 does not have MP5 implemented using a RHF reference.
# :::

# %%
import psi4
import py3Dmol
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append("..")
from helpers import *

# %%
psi4.set_num_threads(2)
psi4.set_memory('2 GB')
# Out:
#   Threads set to 2 by Python driver.
#
#   Memory set to   1.863 GiB by Python driver.
# 2000000000

# %%
psi4.core.clean_options()

# define a single boron atom and set the correct multiplicity
boron_geometry = psi4.geometry("""
0 2
B 0.0 0.0 0.0
""")

psi4.set_options({'reference' : "UHF"})

# Perform single-point calculation with requested method/basis 
B_energy_hf  = psi4.energy(f'hf/{'6-311+G**'}', molecule=boron_geometry)
# Out:
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on noto.epfl.ch
# *** at Fri Oct 10 22:50:26 2025
#
#    => Loading Basis Set <=
#
#     Name: 6-311+G**
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry B          line   108 file /opt/CompChem/psi4conda-1.9.1/share/psi4/basis/6-311pgss.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               UHF Reference
#                         2 Threads,   1907 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Geometry (in Angstrom), charge = 0, multiplicity = 2:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          B            0.000000000000     0.000000000000     0.000000000000    11.009305360000
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B = ************  C = ************ [cm^-1]
#   Rotational constants: A = ************  B = ************  C = ************ [MHz]
#   Nuclear repulsion =    0.000000000000000
#
#   Charge       = 0
#   Multiplicity = 2
#   Electrons    = 5
#   Nalpha       = 3
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     2,    0,    0,    0,    0,    0,    0,    0 ]
#     SOCC [     0,    0,    0,    0,    0,    1,    0,    0 ]
#     NA   [     2,    0,    0,    0,    0,    1,    0,    0 ]
#     NB   [     2,    0,    0,    0,    0,    0,    0,    0 ]
#
#   @DF-UHF Final Energy:   -24.53034517277242
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.0000000000000000
#     One-Electron Energy =                 -32.3682323022668115
#     Two-Electron Energy =                   7.8378871294943888
#     Total Energy =                        -24.5303451727724209
#
#   UHF NO Occupations:
#   HONO-2 :    1 Ag 1.9999997
#   HONO-1 :    2 Ag 1.9964863
#   HONO-0 :    1B1u 1.0000000
#   LUNO+0 :    3 Ag 0.0035137
#   LUNO+1 :    4 Ag 0.0000003
#   LUNO+2 :    5 Ag 0.0000000
#   LUNO+3 :    2B1u 0.0000000
#
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on noto.epfl.ch at Fri Oct 10 22:50:26 2025
# Module time:
# 	user time   =       0.45 seconds =       0.01 minutes
# 	system time =       0.04 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.45 seconds =       0.01 minutes
# 	system time =       0.04 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes

# %%
drawXYZ(boron_geometry)
# Out:
# <div id="3dmolviewer_17601294264569073"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17601294264569073" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17601294264569073 = null;
# var warn = document.getElementById("3dmolwarning_17601294264569073");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17601294264569073 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17601294264569073"),{backgroundColor:"white"});
# viewer_17601294264569073.zoomTo();
# 	viewer_17601294264569073.addModel("1\n\n B    0.000000000000    0.000000000000    0.000000000000\n","xyz");
# 	viewer_17601294264569073.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17601294264569073.zoomTo();
# viewer_17601294264569073.render();
# });
# </script>

# %%
#Experimental energy of Boron
B_exact_e = -24.608

correlation = B_exact_e - B_energy_hf # Calculate the total amount of correlation energy that should be recovered using the B_exact_e

print(F"\n Electron correlation: {correlation} Hartrees")
# Out:
#  Electron correlation: -0.07765482722757966 Hartrees

# %%
# calculate energy for other methods
psi4.core.clean_options()
psi4.core.clean()
psi4.set_options({'reference' : "UHF"})
#MP2
e_mp2 = None
#MP3
e_mp3 = None
#CCSD
e_ccsd = None
#CCSD(T)
e_ccsd_t = None
#MP5
psi4.core.clean_options()
psi4.core.clean()
psi4.set_options({"reference" :"rohf", 
                   "qc_module":"detci"})
e_mp5 = None
#CISD
e_cisd = None
#FCI
e_fci = None

# %%
# calculate energy for other methods
psi4.core.clean_options()
psi4.core.clean()

# --- Coupled-cluster & low-order MP with UHF reference ---
psi4.set_options({'reference': 'UHF'})

# MP2 / MP3
e_mp2   = psi4.energy('mp2/6-311+G**',molecule=boron_geometry)
e_mp3   = psi4.energy('mp3/6-311+G**',molecule=boron_geometry)

# CCSD and CCSD(T)
# (with reference='UHF' Psi4 runs the unrestricted variants under the hood)
e_ccsd   = psi4.energy('ccsd/6-311+G**',molecule=boron_geometry)
e_ccsd_t = psi4.energy('ccsd(t)/6-311+G**',molecule=boron_geometry)   # you could also read CCSD from this output

# --- High-order MP and CI with ROHF + detci (as required by Psi4 for MP5) ---
psi4.core.clean_options()
psi4.core.clean()
psi4.set_options({'reference': 'rohf', 'qc_module': 'detci'})

# MP5 (via detci)
e_mp5  = psi4.energy('mp5/6-311+G**',molecule=boron_geometry)

# CI
e_cisd = psi4.energy('cisd/6-311+G**',molecule=boron_geometry)
e_fci  = psi4.energy('fci/6-311+G**',molecule=boron_geometry)
# Out:
# Scratch directory: /tmp/
#     SCF Algorithm Type (re)set to DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on noto.epfl.ch
# *** at Fri Oct 10 22:50:26 2025
#
#    => Loading Basis Set <=
#
#     Name: 6-311+G**
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry B          line   108 file /opt/CompChem/psi4conda-1.9.1/share/psi4/basis/6-311pgss.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               UHF Reference
#                         2 Threads,   1907 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Geometry (in Angstrom), charge = 0, multiplicity = 2:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          B            0.000000000000     0.000000000000     0.000000000000    11.009305360000
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B = ************  C = ************ [cm^-1]
#   Rotational constants: A = ************  B = ************  C = ************ [MHz]
#   Nuclear repulsion =    0.000000000000000
#
#   Charge       = 0
#   Multiplicity = 2
#   Electrons    = 5
#   Nalpha       = 3
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is CORE.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-311+G**
#     Blend: 6-311+G**
#     Number of shells: 10
#     Number of basis functions: 22
#     Number of Cartesian functions: 23
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (6-311+G** AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1 entry B          line   138 file /opt/CompChem/psi4conda-1.9.1/share/psi4/basis/heavy-aug-cc-pvtz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.001 GiB; user supplied 1.397 GiB.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               2
#     Memory [MiB]:              1430
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-311+G** AUX)
#     Blend: HEAVY-AUG-CC-PVTZ-JKFIT
#     Number of shells: 30
#     Number of basis functions: 104
#     Number of Cartesian functions: 131
#     Spherical Harmonics?: true
#     Max angular momentum: 4
#
#   Minimum eigenvalue in the overlap matrix is 6.7945151576E-02.
#   Reciprocal condition number of the overlap matrix is 2.5371712151E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Core (One-Electron) Hamiltonian.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      Ag         7       7       1       1       1       0
#      B1g        1       1       0       0       0       0
#      B2g        1       1       0       0       0       0
#      B3g        1       1       0       0       0       0
#      Au         0       0       0       0       0       0
#      B1u        4       4       1       0       0       1
#      B2u        4       4       0       0       0       0
#      B3u        4       4       1       1       1       0
#    -------------------------------------------------------
#     Total      22      22       3       2       2       1
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#     Occupation by irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     2,    0,    0,    0,    0,    0,    0,    0 ]
#     SOCC [     0,    0,    0,    0,    0,    1,    0,    0 ]
#     NA   [     2,    0,    0,    0,    0,    1,    0,    0 ]
#     NB   [     2,    0,    0,    0,    0,    0,    0,    0 ]
#
#    @DF-UHF iter   1:   -21.90768345320183   -2.19077e+01   2.25456e-01 ADIIS
#    @DF-UHF iter   2:   -23.41357942588769   -1.50590e+00   5.99293e-02 DIIS/ADIIS
#    @DF-UHF iter   3:   -24.48999660241709   -1.07642e+00   2.09428e-02 DIIS/ADIIS
#    @DF-UHF iter   4:   -24.52755780427946   -3.75612e-02   4.94264e-03 DIIS/ADIIS
#    @DF-UHF iter   5:   -24.53027653381340   -2.71873e-03   6.96897e-04 DIIS/ADIIS
#    @DF-UHF iter   6:   -24.53033942987107   -6.28961e-05   1.65014e-04 DIIS/ADIIS
#    @DF-UHF iter   7:   -24.53034455110495   -5.12123e-06   4.52397e-05 DIIS
#    @DF-UHF iter   8:   -24.53034515231157   -6.01207e-07   8.61797e-06 DIIS
#    @DF-UHF iter   9:   -24.53034517242196   -2.01104e-08   1.24649e-06 DIIS
#    @DF-UHF iter  10:   -24.53034517277243   -3.50472e-10   2.06738e-07 DIIS
#    @DF-UHF iter  11:   -24.53034517278261   -1.01821e-11   3.23300e-08 DIIS
#    @DF-UHF iter  12:   -24.53034517278278   -1.74083e-13   3.39053e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    @Spin Contamination Metric
# 	   ALPHA       0       3       3      19      19       0
# 	    BETA       0       2       2      20      20       0
# 	 --------------------------------------------------------
#
# 	-----------------------------------------------------------
# 	 ==================> DF-MP2 Energies <====================
# 	-----------------------------------------------------------
# 	 Reference Energy          =     -24.5303451727827841 [Eh]
# 	 Singles Energy            =      -0.0000000000000000 [Eh]
# 	 Same-Spin Energy          =      -0.0036131208676099 [Eh]
# 	 Opposite-Spin Energy      =      -0.0523312814713490 [Eh]
# 	 Correlation Energy        =      -0.0559444023389589 [Eh]
# 	 Total Energy              =     -24.5862895751217430 [Eh]
# 	-----------------------------------------------------------
# 	 ================> DF-SCS-MP2 Energies <==================
# 	-----------------------------------------------------------
# 	 SCS Same-Spin Scale       =       0.3333333333333333 [-]
# 	 SCS Opposite-Spin Scale   =       1.2000000000000000 [-]
# 	 SCS Same-Spin Energy      =      -0.0012043736225366 [Eh]
# 	 SCS Opposite-Spin Energy  =      -0.0627975377656188 [Eh]
# 	 SCS Correlation Energy    =      -0.0640019113881554 [Eh]
# 	 SCS Total Energy          =     -24.5943470841709413 [Eh]
# 	-----------------------------------------------------------
#
#
# *** tstop() called on noto.epfl.ch at Fri Oct 10 22:50:26 2025
# Module time:
# 	user time   =       0.08 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.91 seconds =       0.02 minutes
# 	system time =       0.08 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
#
# Scratch directory: /tmp/
#     Information: MP3 default algorithm changed to DF in August 2020. Use `set mp_type conv` for previous behavior.
#     For method 'MP3', SCF Algorithm Type (re)set to DISK_DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on noto.epfl.ch
# *** at Fri Oct 10 22:50:26 2025
#
#    => Loading Basis Set <=
#
#     Name: 6-311+G**
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry B          line   108 file /opt/CompChem/psi4conda-1.9.1/share/psi4/basis/6-311pgss.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               UHF Reference
#                         2 Threads,   1907 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Geometry (in Angstrom), charge = 0, multiplicity = 2:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          B            0.000000000000     0.000000000000     0.000000000000    11.009305360000
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B = ************  C = ************ [cm^-1]
#   Rotational constants: A = ************  B = ************  C = ************ [MHz]
#   Nuclear repulsion =    0.000000000000000
#
#   Charge       = 0
#   Multiplicity = 2
#   Electrons    = 5
#   Nalpha       = 3
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DISK_DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is CORE.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-311+G**
#     Blend: 6-311+G**
#     Number of shells: 10
#     Number of basis functions: 22
#     Number of Cartesian functions: 23
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (6-311+G** AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1 entry B          line   138 file /opt/CompChem/psi4conda-1.9.1/share/psi4/basis/heavy-aug-cc-pvtz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   ==> DiskDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              2
#     Integrals threads:           2
#     Memory [MiB]:             1430
#     Algorithm:                Core
#     Integral Cache:           SAVE
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-311+G** AUX)
#     Blend: HEAVY-AUG-CC-PVTZ-JKFIT
#     Number of shells: 30
#     Number of basis functions: 104
#     Number of Cartesian functions: 131
#     Spherical Harmonics?: true
#     Max angular momentum: 4
#
#   Minimum eigenvalue in the overlap matrix is 6.7945151576E-02.
#   Reciprocal condition number of the overlap matrix is 2.5371712151E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Core (One-Electron) Hamiltonian.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      Ag         7       7       1       1       1       0
#      B1g        1       1       0       0       0       0
#      B2g        1       1       0       0       0       0
#      B3g        1       1       0       0       0       0
#      Au         0       0       0       0       0       0
#      B1u        4       4       1       0       0       1
#      B2u        4       4       0       0       0       0
#      B3u        4       4       1       1       1       0
#    -------------------------------------------------------
#     Total      22      22       3       2       2       1
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on noto.epfl.ch at Fri Oct 10 22:50:26 2025
# Module time:
# 	user time   =       0.23 seconds =       0.00 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       1.19 seconds =       0.02 minutes
# 	system time =       0.10 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
#
#   A requested method does not make use of molecular symmetry: further calculations in C1 point group.
#
#   Constructing Basis Sets for DFOCC...
#
#    => Loading Basis Set <=
#
#     Name: (6-311+G** AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1 entry B          line   138 file /opt/CompChem/psi4conda-1.9.1/share/psi4/basis/heavy-aug-cc-pvtz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: (6-311+G** AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_CC
#     atoms 1 entry B          line    90 file /opt/CompChem/psi4conda-1.9.1/share/psi4/basis/heavy-aug-cc-pvtz-ri.gbs
#
#
# *** tstart() called on noto.epfl.ch
# *** at Fri Oct 10 22:50:26 2025
#
#
#
#   Module DFOCC Options:
#   ----------------------------------------------------------------------------
#   ACTIVE                        => (empty)
#   BASIS_RELATIVISTIC            => (empty)
#   BENCH                         => (empty)
#   CC_DIIS_MAX_VECS              => (empty)
#   CC_DIIS_MIN_VECS              => (empty)
#   CC_LAMBDA                     => (empty)
#   CC_MAXITER                    => (empty)
#   CC_TYPE                       => (empty)
#   CHOLESKY                      => FALSE           !
#   CHOLESKY_TOLERANCE            => (empty)
#   CI_TYPE                       => (empty)
#   COMPUT_S2                     => (empty)
#   CUBEPROP_BASIS_FUNCTIONS      => (empty)
#   CUBEPROP_FILEPATH             => (empty)
#   CUBEPROP_ISOCONTOUR_THRESHOLD => (empty)
#   CUBEPROP_ORBITALS             => (empty)
#   CUBEPROP_TASKS                => (empty)
#   CUBIC_BASIS_TOLERANCE         => (empty)
#   CUBIC_BLOCK_MAX_POINTS        => (empty)
#   CUBIC_GRID_OVERAGE            => (empty)
#   CUBIC_GRID_SPACING            => (empty)
#   CUTOFF                        => (empty)
#   DDX                           => (empty)
#   DEBUG                         => (empty)
#   DERTYPE                       => (empty)
#   DF_BASIS_CC                   => (empty)
#   DIE_IF_NOT_CONVERGED          => (empty)
#   DKH_ORDER                     => (empty)
#   DOCC                          => (empty)
#   DO_DIIS                       => (empty)
#   DO_LEVEL_SHIFT                => (empty)
#   DO_SCS                        => FALSE           !
#   DO_SOS                        => FALSE           !
#   E3_SCALE                      => (empty)
#   EKT_IP                        => (empty)
#   EXTERNAL_POTENTIAL_SYMMETRY   => (empty)
#   E_CONVERGENCE                 => 1e-06           !
#   FREEZE_CORE                   => (empty)
#   FREEZE_CORE_POLICY            => (empty)
#   FROZEN_DOCC                   => (empty)
#   FROZEN_UOCC                   => (empty)
#   HESS_TYPE                     => (empty)
#   INTEGRAL_CUTOFF               => (empty)
#   INTEGRAL_PACKAGE              => (empty)
#   LEVEL_SHIFT                   => (empty)
#   LINEQ_SOLVER                  => (empty)
#   LITERAL_CFOUR                 => (empty)
#   MAT_NUM_COLUMN_PRINT          => (empty)
#   MAX_MOGRAD_CONVERGENCE        => (empty)
#   MAX_RADIAL_MOMENT             => (empty)
#   MBIS_D_CONVERGENCE            => (empty)
#   MBIS_MAXITER                  => (empty)
#   MBIS_PRUNING_SCHEME           => (empty)
#   MBIS_RADIAL_POINTS            => (empty)
#   MBIS_SPHERICAL_POINTS         => (empty)
#   MOLDEN_WITH_VIRTUAL           => (empty)
#   MOLDEN_WRITE                  => (empty)
#   MO_DIIS_NUM_VECS              => (empty)
#   MO_MAXITER                    => (empty)
#   MO_STEP_MAX                   => (empty)
#   MP2_AMP_TYPE                  => (empty)
#   MP2_OS_SCALE                  => (empty)
#   MP2_SOS_SCALE                 => (empty)
#   MP2_SOS_SCALE2                => (empty)
#   MP2_SS_SCALE                  => (empty)
#   MP2_TYPE                      => (empty)
#   MP_TYPE                       => (empty)
#   NAT_ORBS                      => FALSE           !
#   NUM_FROZEN_DOCC               => (empty)
#   NUM_FROZEN_UOCC               => (empty)
#   NUM_GPUS                      => (empty)
#   OCC_ORBS_PRINT                => (empty)
#   OEPROP                        => (empty)
#   OO_SCALE                      => (empty)
#   OPT_METHOD                    => (empty)
#   ORB_OPT                       => FALSE           !
#   ORB_RESP_SOLVER               => (empty)
#   ORTH_TYPE                     => (empty)
#   PARENT_SYMMETRY               => (empty)
#   PCG_BETA_TYPE                 => (empty)
#   PCG_CONVERGENCE               => (empty)
#   PCG_MAXITER                   => (empty)
#   PCM                           => (empty)
#   PE                            => (empty)
#   PPL_TYPE                      => (empty)
#   PRINT                         => (empty)
#   PRINT_NOONS                   => (empty)
#   PROPERTIES                    => (empty)
#   PROPERTIES_ORIGIN             => (empty)
#   PUREAM                        => (empty)
#   QCHF                          => (empty)
#   QC_MODULE                     => (empty)
#   RAS1                          => (empty)
#   RAS2                          => (empty)
#   RAS3                          => (empty)
#   RAS4                          => (empty)
#   READ_SCF_3INDEX               => (empty)
#   REGULARIZATION                => (empty)
#   REG_PARAM                     => (empty)
#   RELATIVISTIC                  => (empty)
#   REMP_A                        => (empty)
#   RESTRICTED_DOCC               => (empty)
#   RESTRICTED_UOCC               => (empty)
#   RMS_MOGRAD_CONVERGENCE        => (empty)
#   R_CONVERGENCE                 => (empty)
#   SCF_TYPE                      => DISK_DF         !
#   SCREENING                     => (empty)
#   SCS_TYPE                      => (empty)
#   SOCC                          => (empty)
#   SOS_TYPE                      => (empty)
#   TRIPLES_IABC_TYPE             => (empty)
#   WFN                           => (empty)
#   WFN_TYPE                      => DF-OMP3         !
#   WRITER_FILE_LABEL             => (empty)
#
# 	For this residual convergence, default PCG convergence is:     1.00e-07
# 	For this energy convergence, default residual convergence is:     3.16e-07
#
#  ==============================================================================
#  ==============================================================================
#  ==============================================================================
#
#                      DF-MP3
#               Program Written by Ugur Bozkaya
#               Latest Revision September 9, 2017
#
#  ==============================================================================
#  ==============================================================================
#  ==============================================================================
#
# 	MO spaces...
#
# 	 FC   AOCC   BOCC  AVIR   BVIR   FV
# 	------------------------------------------
# 	  0     3     2    19     20     0
#
# 	Number of basis functions in the DF-CC basis: 106
#
# 	Available memory                      :   1907.35 MB
# 	Memory requirement for 3-index ints   :      0.69 MB
# 	Memory requirement for DF-CC int trans:      1.02 MB
# 	Memory requirement for CC contractions:      0.10 MB
# 	Total memory requirement for DF+CC int:      0.44 MB
# 	Memory requirement for Wabef term     :      0.66 MB
#
# 	Computing DF-MP2 energy ...
# 	=======================================================================
# 	Nuclear Repulsion Energy (a.u.)    :     0.00000000000000
# 	DF-HF Energy (a.u.)                :   -24.53034517278281
# 	REF Energy (a.u.)                  :   -24.53034517278281
# 	Alpha-Alpha Contribution (a.u.)    :    -0.00331023437927
# 	Alpha-Beta Contribution (a.u.)     :    -0.05233128147135
# 	Beta-Beta Contribution (a.u.)      :    -0.00030288648834
# 	Scaled_SS Correlation Energy (a.u.):    -0.00120437362254
# 	Scaled_OS Correlation Energy (a.u.):    -0.06279753776562
# 	DF-SCS-MP2 Total Energy (a.u.)     :   -24.59434708417097
# 	DF-SOS-MP2 Total Energy (a.u.)     :   -24.59837583869557
# 	DF-SCS(N)-MP2 Total Energy (a.u.)  :   -24.53670426550980
# 	DF-MP2 Correlation Energy (a.u.)   :    -0.05594440233896
# 	DF-MP2 Total Energy (a.u.)         :   -24.58628957512177
# 	=======================================================================
#
# 	=======================================================================
# 	================ MP3 FINAL RESULTS ====================================
# 	=======================================================================
# 	Nuclear Repulsion Energy (a.u.)    :     0.00000000000000
# 	SCF Energy (a.u.)                  :   -24.53034517278281
# 	REF Energy (a.u.)                  :   -24.53034517278281
# 	Alpha-Alpha Contribution (a.u.)    :    -0.00390973643200
# 	Alpha-Beta Contribution (a.u.)     :    -0.06623990241161
# 	Beta-Beta Contribution (a.u.)      :    -0.00030653679388
# 	3rd Order Energy (a.u.)            :    -0.01451177329853
# 	DF-MP2.5 Correlation Energy (a.u.) :    -0.06320028898823
# 	DF-MP2.5 Total Energy (a.u.)       :   -24.59354546177104
# 	DF-MP3 Correlation Energy (a.u.)   :    -0.07045617563749
# 	DF-MP3 Total Energy (a.u.)         :   -24.60080134842030
# 	=======================================================================
#
#
# *** tstop() called on noto.epfl.ch at Fri Oct 10 22:50:27 2025
# Module time:
# 	user time   =       0.50 seconds =       0.01 minutes
# 	system time =       0.03 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       1.74 seconds =       0.03 minutes
# 	system time =       0.13 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on noto.epfl.ch
# *** at Fri Oct 10 22:50:27 2025
#
#    => Loading Basis Set <=
#
#     Name: 6-311+G**
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry B          line   108 file /opt/CompChem/psi4conda-1.9.1/share/psi4/basis/6-311pgss.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               UHF Reference
#                         2 Threads,   1907 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Geometry (in Angstrom), charge = 0, multiplicity = 2:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          B            0.000000000000     0.000000000000     0.000000000000    11.009305360000
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B = ************  C = ************ [cm^-1]
#   Rotational constants: A = ************  B = ************  C = ************ [MHz]
#   Nuclear repulsion =    0.000000000000000
#
#   Charge       = 0
#   Multiplicity = 2
#   Electrons    = 5
#   Nalpha       = 3
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is CORE.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-311+G**
#     Blend: 6-311+G**
#     Number of shells: 10
#     Number of basis functions: 22
#     Number of Cartesian functions: 23
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   1
#       Number of AO shells:              10
#       Number of primitives:             19
#       Number of atomic orbitals:        23
#       Number of basis functions:        22
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 2
#
#   Performing in-core PK
#   Using 64262 doubles for integral storage.
#   We computed 1800 shell quartets total.
#   Whereas there are 1540 unique shell quartets.
#     16.88 percent of shell quartets recomputed by reordering.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:             1430
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.0000000000000000
#     One-Electron Energy =                 -32.3682713224271055
#     Two-Electron Energy =                   7.8379225399927961
#     Total Energy =                        -24.5303487824343094
#
#   UHF NO Occupations:
#   HONO-2 :    1 Ag 1.9999997
#   HONO-1 :    2 Ag 1.9964831
#   HONO-0 :    1B1u 1.0000000
#   LUNO+0 :    3 Ag 0.0035169
#   LUNO+1 :    4 Ag 0.0000003
#   LUNO+2 :    5 Ag 0.0000000
#   LUNO+3 :    6 Ag 0.0000000
#
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on noto.epfl.ch at Fri Oct 10 22:50:27 2025
# Module time:
# 	user time   =       0.21 seconds =       0.00 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       2.00 seconds =       0.03 minutes
# 	system time =       0.15 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 2
#       Number of atoms:                   1
#       Number of AO shells:              10
#       Number of SO shells:              10
#       Number of primitives:             19
#       Number of atomic orbitals:        23
#       Number of basis functions:        22
#
#       Number of irreps:                  8
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [   7    1    1    1    0    4    4    4 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 4475 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on noto.epfl.ch
# *** at Fri Oct 10 22:50:27 2025
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD
# 	Number of irreps     = 8
# 	Number of MOs        = 22
# 	Number of active MOs = 22
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = UHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   7	    0	    2	    0	    5	    0
# 	 B1g	   1	    0	    0	    0	    1	    0
# 	 B2g	   1	    0	    0	    0	    1	    0
# 	 B3g	   1	    0	    0	    0	    1	    0
# 	 Au	   0	    0	    0	    0	    0	    0
# 	 B1u	   4	    0	    0	    1	    3	    0
# 	 B2u	   4	    0	    0	    0	    4	    0
# 	 B3u	   4	    0	    0	    0	    4	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <AB|CD> integrals:      0.001 (MW) /      0.005 (MB)
# 	Size of irrep 1 of <AB|CD> integrals:      0.000 (MW) /      0.004 (MB)
# 	Size of irrep 2 of <AB|CD> integrals:      0.000 (MW) /      0.003 (MB)
# 	Size of irrep 3 of <AB|CD> integrals:      0.000 (MW) /      0.003 (MB)
# 	Size of irrep 4 of <AB|CD> integrals:      0.000 (MW) /      0.001 (MB)
# 	Size of irrep 5 of <AB|CD> integrals:      0.001 (MW) /      0.004 (MB)
# 	Size of irrep 6 of <AB|CD> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 7 of <AB|CD> integrals:      0.001 (MW) /      0.006 (MB)
# 	Total:                                     0.004 (MW) /      0.031 (MB)
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.000 (MW) /      0.004 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.000 (MW) /      0.004 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.000 (MW) /      0.004 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.000 (MW) /      0.001 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.001 (MW) /      0.006 (MB)
# 	Total:                                     0.005 (MW) /      0.038 (MB)
#
# 	Size of irrep 0 of <Ab|Cd> integrals:      0.005 (MW) /      0.041 (MB)
# 	Size of irrep 1 of <Ab|Cd> integrals:      0.002 (MW) /      0.015 (MB)
# 	Size of irrep 2 of <Ab|Cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 3 of <Ab|Cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 4 of <Ab|Cd> integrals:      0.001 (MW) /      0.004 (MB)
# 	Size of irrep 5 of <Ab|Cd> integrals:      0.003 (MW) /      0.021 (MB)
# 	Size of irrep 6 of <Ab|Cd> integrals:      0.003 (MW) /      0.024 (MB)
# 	Size of irrep 7 of <Ab|Cd> integrals:      0.003 (MW) /      0.024 (MB)
# 	Total:                                     0.019 (MW) /      0.156 (MB)
#
# 	Size of irrep 0 of <IA|BC> integrals:      0.001 (MW) /      0.007 (MB)
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B = ************  C = ************ [cm^-1]
#   Rotational constants: A = ************  B = ************  C = ************ [MHz]
#   Nuclear repulsion =    0.000000000000000
#
#   Charge       = 0
#   Multiplicity = 2
#   Electrons    = 5
#   Nalpha       = 3
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is CORE.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-311+G**
#     Blend: 6-311+G**
#     Number of shells: 10
#     Number of basis functions: 22
#     Number of Cartesian functions: 23
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   1
#       Number of AO shells:              10
#       Number of primitives:             19
#       Number of atomic orbitals:        23
#       Number of basis functions:        22
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 2
#
#   Performing in-core PK
#   Using 64262 doubles for integral storage.
#   We computed 1800 shell quartets total.
#   Whereas there are 1540 unique shell quartets.
#     16.88 percent of shell quartets recomputed by reordering.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:             1430
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              2
#
#   Minimum eigenvalue in the overlap matrix is 6.7945151576E-02.
#   Reciprocal condition number of the overlap matrix is 2.5371712151E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Core (One-Electron) Hamiltonian.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      Ag         7       7       1       1       1       0
#      B1g        1       1       0       0       0       0
#      B2g        1       1       0       0       0       0
#      B3g        1       1       0       0       0       0
#      Au         0       0       0       0       0       0
#      B1u        4       4       1       0       0       1
#      B2u        4       4       0       0       0       0
#      B3u        4       4       1       1       1       0
#    -------------------------------------------------------
#     Total      22      22       3       2       2       1
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#     Occupation by irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     2,    0,    0,    0,    0,    0,    0,    0 ]
#     SOCC [     0,    0,    0,    0,    0,    0,    0,    1 ]
#     NA   [     2,    0,    0,    0,    0,    0,    0,    1 ]
#     NB   [     2,    0,    0,    0,    0,    0,    0,    0 ]
#
#    @ROHF iter   1:   -21.90771212465790   -2.19077e+01   1.71305e-01 DIIS
#    @ROHF iter   2:   -23.34570215354508   -1.43799e+00   4.38671e-02 DIIS
#    @ROHF iter   3:   -24.49290614502939   -1.14720e+00   1.62067e-02 DIIS
#    @ROHF iter   4:   -24.52576729237588   -3.28611e-02   3.15639e-03 DIIS
#    @ROHF iter   5:   -24.52703113793030   -1.26385e-03   3.52847e-04 DIIS
#    @ROHF iter   6:   -24.52707969637584   -4.85584e-05   1.39661e-04 DIIS
#    @ROHF iter   7:   -24.52708523681352   -5.54044e-06   3.54425e-05 DIIS
#    @ROHF iter   8:   -24.52708562928479   -3.92471e-07   4.32982e-06 DIIS
#    @ROHF iter   9:   -24.52708563270540   -3.42061e-09   5.63358e-07 DIIS
#    @ROHF iter  10:   -24.52708563278072   -7.53211e-11   5.37789e-08 DIIS
#    @ROHF iter  11:   -24.52708563278128   -5.64881e-13   2.40394e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1Ag    -7.694984     2Ag    -0.495103
#
#     Singly Occupied:
#
#        1B3u   -0.086307
#
#     Virtual:
#
#        1B1u    0.032528     1B2u    0.032528     3Ag     0.077346
#        2B3u    0.099108     2B2u    0.129420     2B1u    0.129420
#        3B3u    0.527144     3B1u    0.541649     3B2u    0.541649
#        4Ag     0.585258     5Ag     1.036657     1B3g    1.036657
#        1B2g    1.044655     1B1g    1.044655     6Ag     1.047337
#        4B1u    2.078443     4B2u    2.078443     4B3u    2.090730
#        7Ag    14.682229
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     2,    0,    0,    0,    0,    0,    0,    0 ]
#     SOCC [     0,    0,    0,    0,    0,    0,    0,    1 ]
#     NA   [     2,    0,    0,    0,    0,    0,    0,    1 ]
#     NB   [     2,    0,    0,    0,    0,    0,    0,    0 ]
#
#   @ROHF Final Energy:   -24.52708563278128
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.0000000000000000
#     One-Electron Energy =                 -32.3640769489243638
#     Two-Electron Energy =                   7.8369913161430800
#     Total Energy =                        -24.5270856327812830
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on noto.epfl.ch at Fri Oct 10 22:50:40 2025
# Module time:
# 	user time   =       0.16 seconds =       0.00 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       7.48 seconds =       0.12 minutes
# 	system time =       0.90 seconds =       0.02 minutes
# 	total time  =         14 seconds =       0.23 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 2
#       Number of atoms:                   1
#       Number of AO shells:              10
#       Number of SO shells:              10
#       Number of primitives:             19
#       Number of atomic orbitals:        23
#       Number of basis functions:        22
#
#       Number of irreps:                  8
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [   7    1    1    1    0    4    4    4 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 4475 non-zero two-electron integrals.
#         Stored in file 33.
#
#
#          ---------------------------------------------------------
#                           Configuration Interaction
#                             (a 'D E T C I' module)
#
#                  C. David Sherrill, Daniel G. A. Smith, and
#                               Matt L. Leininger
#          ---------------------------------------------------------
#
# Warning: iopen=0,opentype!=closed. Making iopen=1
#
#    ==> Parameters <==
#
#     EX LEVEL       =        5      H0 BLOCKSIZE  =     1000
#     VAL EX LEVEL   =        0      H0 GUESS SIZE =     1000
#     H0COUPLINGSIZE =        0      H0 COUPLING   =       NO
#     MAXITER        =       24      NUM PRINT     =       20
#     NUM ROOTS      =        1      ICORE         =        1
#     PRINT LVL      =        1      FCI           =      YES
#     R CONV         = 1.00e-04      MIXED         =      YES
#     E CONV         = 1.00e-06      MIXED4        =      YES
#     R4S            =       NO      REPL OTF      =       NO
#     DIAG METHOD    =      SEM      FOLLOW ROOT   =        0
#     PRECONDITIONER = DAVIDSON      UPDATE        = DAVIDSON
#     S              =   0.5000      Ms0           =       NO
#     GUESS VECTOR   =  H0BLOCK      OPENTYPE      = HIGHSPIN
#     COLLAPSE SIZE  =        1      HD AVG        = EVANGELISTI
#     MAX NUM VECS   =       25      REF SYM       =     AUTO
#     IOPEN        =      YES
#
#     EX ALLOW       =  1  1  1  1  1
#     STATE AVERAGE  =  0(1.00)
#
#    ==> CI Orbital and Space information <==
#
#    ------------------------------------------------------------------------------
#                Space    Total    Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#    ------------------------------------------------------------------------------
#                  Nso       22     7     1     1     1     0     4     4     4
#                  Nmo       22     7     1     1     1     0     4     4     4
#                Ndocc        2     2     0     0     0     0     0     0     0
#                Nsocc        1     0     0     0     0     0     0     0     1
#    ------------------------------------------------------------------------------
#                                    CI Spaces
#    ------------------------------------------------------------------------------
#         Dropped DOCC        0     0     0     0     0     0     0     0     0
#               Active       22     7     1     1     1     0     4     4     4
#         Dropped UOCC        0     0     0     0     0     0     0     0     0
#    ------------------------------------------------------------------------------
#
#    ==> Setting up CI strings <==
#
#     There are 1540 alpha and 231 beta strings
#     The CI space requires 44760 (4.48E+04) determinants and 8 blocks
#
#    ==> Transforming CI integrals <==
#
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
#
#    ==> Starting CI iterations <==
#
#     H0 Block Eigenvalue = -24.59284606
#
#     Simultaneous Expansion Method (Block Davidson Method)
#     Using 1 initial trial vectors
#
#      Iter   Root       Total Energy       Delta E      C RMS
#
#    @CI  0:     0    -24.592846058291   -2.4593E+01   7.4692E-01
#    @CI  1:     0    -24.610001293039   -1.7155E-02   2.7063E-02
#    @CI  2:     0    -24.610042822166   -4.1529E-05   3.2569E-03
#    @CI  3:     0    -24.610043862412   -1.0402E-06   9.7178E-04
#    @CI  4:     0    -24.610043964177   -1.0176E-07   2.6273E-04
#    @CI  5:     0    -24.610043975089   -1.0912E-08   9.6930E-05 c
#
#    ==> Energetics <==
#
#     SCF energy =          -24.527085632781283
#     Total CI energy =     -24.610043975088740
#
#    ==> FCI root 0 information <==
#
#     FCI Root 0 energy =   -24.610043975088740
#
#    The 20 most important determinants:
#
#     *   1    0.963939  ( 1340,    0)  1AgX 2AgX 1B3uA
#     *   2    0.074353  (  428,  124)  1AgX 1B3uA 1B1uX
#     *   3    0.074353  (  248,  164)  1AgX 1B3uA 1B2uX
#     *   4    0.068316  (  435,  124)  1AgX 1B3uA 1B1uB 2B1uA
#     *   5    0.068316  (  259,  164)  1AgX 1B3uA 1B2uB 2B2uA
#     *   6    0.067963  (  428,  131)  1AgX 1B3uA 1B1uA 2B1uB
#     *   7    0.067963  (  248,  171)  1AgX 1B3uA 1B2uA 2B2uB
#     *   8    0.063065  (  435,  131)  1AgX 1B3uA 2B1uX
#     *   9    0.063065  (  259,  171)  1AgX 1B3uA 2B2uX
#     *  10    0.057343  (   10,  195)  1AgX 2AgA 1B3uB 6AgA
#     *  11    0.038388  ( 1340,   10)  1AgX 2AgA 1B3uA 6AgB
#     *  12   -0.038296  ( 1470,    3)  1AgX 2AgA 4AgB 3B3uA
#     *  13    0.034189  (  400,  124)  1AgX 2AgA 1B2gA 1B1uB
#     *  14    0.034189  (  210,  164)  1AgX 2AgA 1B1gA 1B2uB
#     *  15    0.033822  (  443,  124)  1AgX 1B3uA 1B1uB 3B1uA
#     *  16    0.033822  (  271,  164)  1AgX 1B3uA 1B2uB 3B2uA
#     *  17    0.033279  (  400,  131)  1AgX 2AgA 1B2gA 2B1uB
#     *  18    0.033279  (  210,  171)  1AgX 2AgA 1B1gA 2B2uB
#     *  19    0.033240  (  428,  138)  1AgX 1B3uA 1B1uA 3B1uB
#     *  20    0.033240  (  248,  178)  1AgX 1B3uA 1B2uA 3B2uB
#
# 		 "A good bug is a dead bug"
#
# 			 - Starship Troopers
#
# 		 "I didn't write FORTRAN.  That's the problem."
#
# 			 - Edward Valeev

# %%
# Print energies for verification
print(f"MP2 Energy: {e_mp2} Hartrees")
print(f"MP3 Energy: {e_mp3} Hartrees")
print(f"CCSD Energy: {e_ccsd} Hartrees")
print(f"CCSD(T) Energy: {e_ccsd_t} Hartrees")
print(f"MP5 Energy: {e_mp5} Hartrees")
print(f"CISD Energy: {e_cisd} Hartrees")
print(f"FCI Energy: {e_fci} Hartrees")
# Out:
# MP2 Energy: -24.586289575121743 Hartrees
# MP3 Energy: -24.6008013484203 Hartrees
# CCSD Energy: -24.60855241969002 Hartrees
# CCSD(T) Energy: -24.609669719516056 Hartrees
# MP5 Energy: -24.60860981858081 Hartrees
# CISD Energy: -24.60742517905756 Hartrees
# FCI Energy: -24.61004397508874 Hartrees

# %%
correlations = {}
correlations['hf']= 0
correlations['mp2']    = None # calculate the % of correlation energy recovered here
correlations['mp3']    = None # calculate the % of correlation energy recovered here
correlations['mp5']    = None # calculate the % of correlation energy recovered here
correlations['ccsd']   = None # calculate the % of correlation energy recovered here
correlations['ccsd(t)'] = None # calculate the % of correlation energy recovered here
correlations['cisd'] = None # calculate the % of correlation energy recovered here
correlations['fci'] = None # calculate the % of correlation energy recovered here

# %%
#Experimental energy of Boron
B_exact_e = -24.608

correlation = B_exact_e - B_energy_hf 

def corr_pct(e_method):
    return 100.0 * (e_method - B_energy_hf) / correlation

correlations = {}
correlations['hf']      = 0.0
correlations['mp2']     = corr_pct(e_mp2)
correlations['mp3']     = corr_pct(e_mp3)
correlations['mp5']     = corr_pct(e_mp5)
correlations['ccsd']    = corr_pct(e_ccsd)
correlations['ccsd(t)'] = corr_pct(e_ccsd_t)
correlations['cisd']    = corr_pct(e_cisd)
correlations['fci']     = corr_pct(e_fci)   # may be >100% with a finite basis

correlations
# Out:
# {'hf': 0.0,
#  'mp2': 72.04240141487692,
#  'mp3': 90.72993677701122,
#  'mp5': 100.78529384789184,
#  'ccsd': 100.71137842905947,
#  'ccsd(t)': 102.15018122590364,
#  'cisd': 99.25977435922296,
#  'fci': 102.63212882149479}

# %%
pd.DataFrame.from_dict(correlations,orient='index',columns=['% correlation recovered'])
# Out:
#          % correlation recovered
# hf                      0.000000
# mp2                    72.042401
# mp3                    90.729937
# mp5                   100.785294
# ccsd                  100.711378
# ccsd(t)               102.150181
# cisd                   99.259774
# fci                   102.632129
