# %% [markdown]
# #### Homolytic Cleavage of the C-F Bond
#
# In this exercise, you will investigate the influence of correlation on
# the BDE in a radical process by comparing Hartree-Fock to MPn results.
# Consider the reaction enthalpy of the homolytic cleavage of the H$_3$C-F
# bond in monofluoro methane:
#
# $$
# \begin{aligned}
# CH_3F \quad \rightarrow \quad H_3C\cdot \quad + \quad F\cdot\end{aligned}
# $$
#
#
# As in the exercise on hydrogen dissociation, you may calculate the bond
# dissociation energy as the difference of the energy of the fragments:
#
#
# $$
# \begin{aligned}
# E^{BDE} =  E^{H_3C\cdot} + E^{F\cdot} - E^{CH_3F}.\end{aligned}
# $$
#
# Experimentally, $E^{BDE}$ for this process was determined to be 109.2 kcal mol$^{-1}$ ([*J. Phys. Chem. A*, **2000**, 104, *436*](https://pubs.acs.org/doi/10.1021/jp002317r)).

# %% [markdown]
# Bond dissociation energies of large systems often require the use of
# large basis sets of triple-$\zeta$ quality; you may either use Pople's
# 6-311+G\* basis, or the larger aug-cc-pVTZ by Dunning and coworkers (the
# choice is up to you; either will take comparably long). As Post-HF
# methods require orbitals that diagonalise the Fock operator (*i.e.* the
# Hartree-Fock orbitals), the HF orbitals will need to be calculated at
# the start of every run.
#
# The Post-HF treatment itself may take some considerable time. It is
# therefore not advisable to run electronic structure calculations with
# computationally expensive methods starting from a random guess for the
# geometry (since this guess may be considerably off the equilibrium). It
# is usually more effective to pre-optimise the geometry at the Hartree-Fock level, and only then carry out the more elaborate calculations on the basis of the converged Hartree-Fock result.
#
# In Psi4 this is easy as the geometry is automatically updated when calling `psi4.optimize()`.  In other electronic structure programs often checkpoint files are written which contain intermediate states of the geometry and/or wavefunction.

# %% [markdown]
# For MP3 and MP4, one often expects the geometry not to change too much
# anymore, and a reasonable estimate for the energy may already be given
# by a single-point calculation on the optimised MP2 geometry.
#
# In general, it is sometimes necessary to optimise the geometry at a
# lower Post-Hartree-Fock level, followed by a higher level single point
# calculation. This is due to a lack of available analytical gradients for
# certain higher order methods (such as MP4), which causes the
# computational time for a geometry optimisation to become exorbitantly
# high.

# %% [markdown]
# :::{admonition} Exercise 2
# :class: exercise
# Perform the calculations below and complete the following table.
#
#  |Method:         |   HF   | MP2  |  MP3  |          Exp.          |
#  | :--------------| :----: | :--- | :---- |  :-------------------- |
#  |$E^{F\cdot}$    |        |      |       |        n/a             |
#  |$E^{H_3C\cdot}$ |        |      |       |        n/a             |
#  |$E^{CH_3F}$     |        |      |       |        n/a             |
#  |$E^{BDE}$       |        |      |       |  109.2 kcal mol$^{-1}$ |
# :::

# %%
import psi4
import py3Dmol
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append("..")
from helpers import *

# %%
psi4.set_num_threads(2)
psi4.set_memory('2 GB')
# Out:
#   Threads set to 2 by Python driver.
#
#   Memory set to   1.863 GiB by Python driver.
# 2000000000

# %%
# setup dictionary to store results in
energies = {'hf':{
                 'ch3f':None,
                 'ch3':None,
                 'f':None
                },
            'mp2':{
                 'ch3f':None,
                 'ch3':None,
                 'f':None
                },
            'mp3':{
                 'ch3f':None,
                 'ch3':None,
                 'f':None
                },
           }

# %% [markdown]
# ### CH3F molecule

# %%
ch3f = psi4.geometry("""
0 1
symmetry c1
    F           -0.642381967195     0.000000095800    -0.000000000108
    C            0.742340417015    -0.000000119001     0.000000000132
    H            1.090184715481    -1.027287458657     0.000000000131
    H            1.090184841794     0.513643534810    -0.889656896780
    H            1.090184842203     0.513643534859     0.889656897127
""")

# %%
drawXYZ(ch3f)
# Out:
# <div id="3dmolviewer_1760378598877453"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_1760378598877453" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_1760378598877453 = null;
# var warn = document.getElementById("3dmolwarning_1760378598877453");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1760378598877453 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1760378598877453"),{backgroundColor:"white"});
# viewer_1760378598877453.zoomTo();
# 	viewer_1760378598877453.addModel("5\n\n F   -0.642381967195    0.000000095800   -0.000000000108\n C    0.742340417015   -0.000000119001    0.000000000132\n H    1.090184715481   -1.027287458657    0.000000000131\n H    1.090184841794    0.513643534810   -0.889656896780\n H    1.090184842203    0.513643534859    0.889656897127\n","xyz");
# 	viewer_1760378598877453.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_1760378598877453.zoomTo();
# viewer_1760378598877453.render();
# });
# </script>

# %%
psi4.core.set_output_file('ch3f.log', False)

# %%
psi4.set_options({'reference':'uhf'}) 
energies['hf']['ch3f'] = psi4.optimize('hf/aug-cc-pvdz')
# Out:
# Optimizer: Optimization complete!

# %%
psi4.set_options({"reference" :"uhf","mp2_type":"conv"})
energies['mp2']['ch3f']  = psi4.optimize('mp2/aug-cc-pvdz')
# Out:
# Optimizer: Optimization complete!

# %% [markdown]
# :::{admonition} Exercise 3
# :class: exercise
# Why is it a reasonable choice to use Hartree-Fock geometries and
#     wavefunctions as a starting point for optimisations at the
#     Post-Hartree-Fock level? What is the advantage and how is this
#     approach justified?
# :::

# %%
energies['mp3']['ch3f'] = psi4.energy('mp3/aug-cc-pvdz')

# %% [markdown]
# :::{admonition} Exercise 4
# :class: exercise
# Why do you think it is reasonable to choose not to carry out a geometry optimisation for mp3?
# :::

# %%
drawXYZ(ch3f)
# Out:
# <div id="3dmolviewer_17603786451615343"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17603786451615343" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17603786451615343 = null;
# var warn = document.getElementById("3dmolwarning_17603786451615343");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17603786451615343 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17603786451615343"),{backgroundColor:"white"});
# viewer_17603786451615343.zoomTo();
# 	viewer_17603786451615343.addModel("5\n\n F   -0.000000036102   -0.652204051906    0.000000000250\n C    0.000000041754    0.755178394839   -0.000000000381\n H    0.520765747086    1.100949930529    0.901992626986\n H    0.520765747755    1.100949930141   -0.901992627399\n H   -1.041531311433    1.100950016991    0.000000000242\n","xyz");
# 	viewer_17603786451615343.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17603786451615343.zoomTo();
# viewer_17603786451615343.render();
# });
# </script>

# %% [markdown]
# ### CH3&middot; radical

# %%
psi4.core.clean_options()
psi4.core.clean()

# %%
ch3_radical = psi4.geometry("""
0 2
symmetry c1
C        0.749   0.000   0.000
H        1.112   0.000   1.028
H        1.112  -0.890  -0.514
H        1.112   0.890  -0.514
""")

# %%
drawXYZ(ch3_radical)
# Out:
# <div id="3dmolviewer_17603786452493193"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17603786452493193" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17603786452493193 = null;
# var warn = document.getElementById("3dmolwarning_17603786452493193");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17603786452493193 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17603786452493193"),{backgroundColor:"white"});
# viewer_17603786452493193.zoomTo();
# 	viewer_17603786452493193.addModel("4\n\n C    0.073053767723    0.000000000000    0.000000000000\n H   -0.289946232277    1.028000000000    0.000000000000\n H   -0.289946232277   -0.514000000000   -0.890000000000\n H   -0.289946232277   -0.514000000000    0.890000000000\n","xyz");
# 	viewer_17603786452493193.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17603786452493193.zoomTo();
# viewer_17603786452493193.render();
# });
# </script>

# %%
psi4.core.set_output_file(f'ch3_radical.log', False)

# %%
psi4.set_options({"reference" :"uhf","guess":"gwh", "opt_coordinates": "both"})
energies['hf']['ch3'] = psi4.optimize('hf/aug-cc-pvdz', molecule=ch3_radical)
# Out:
# 	Change in internal coordinate of 5.33e-01 exceeds limit of 5.00e-01.
# 	Skipping Hessian update for step 1.
# 	Change in internal coordinate of 5.13e-01 exceeds limit of 5.00e-01.
# 	Skipping Hessian update for step 2.
# 	Change in internal coordinate of 6.53e-01 exceeds limit of 5.00e-01.
# 	Skipping Hessian update for step 1.
# 	Change in internal coordinate of 6.23e-01 exceeds limit of 5.00e-01.
# 	Skipping Hessian update for step 2.
# 	Change in internal coordinate of 7.63e-01 exceeds limit of 5.00e-01.
# 	Skipping Hessian update for step 1.
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 8.41e-06
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 2.99e-07
# Optimizer: Optimization complete!

# %%
psi4.set_options({"reference" :"uhf","guess":"gwh", "mp2_type":"conv", "opt_coordinates": "both"})
energies['mp2']['ch3'] = psi4.optimize('mp2/aug-cc-pvdz', molecule=ch3_radical)
# Out:
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 4.34e-07
#
# 	Previous geometry is closer to target in internal coordinates, so using that one.
#
# 	Best geometry has RMS(Delta(q)) = 6.72e-08
# Optimizer: Optimization complete!

# %%
energies['mp3']['ch3'] = psi4.energy('mp3/aug-cc-pvdz', molecule=ch3_radical)

# %%
drawXYZ(ch3_radical)
# Out:
# <div id="3dmolviewer_1760378655854899"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_1760378655854899" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_1760378655854899 = null;
# var warn = document.getElementById("3dmolwarning_1760378655854899");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1760378655854899 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1760378655854899"),{backgroundColor:"white"});
# viewer_1760378655854899.zoomTo();
# 	viewer_1760378655854899.addModel("4\n\n C    0.000074757353    0.000000065137    0.000000000003\n H   -0.000294674163    1.086883000061   -0.000000000050\n H   -0.000297725977   -0.543441887830   -0.941267943799\n H   -0.000297722859   -0.543441887806    0.941267943816\n","xyz");
# 	viewer_1760378655854899.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_1760378655854899.zoomTo();
# viewer_1760378655854899.render();
# });
# </script>

# %% [markdown]
# ### F &middot; radical

# %%
psi4.core.clean_options()
psi4.core.clean()

# %%
f_radical = psi4.geometry("""
0 2
symmetry c1
F       -0.650  -0.000   0.000
""")

# %%
drawXYZ(f_radical)
# Out:
# <div id="3dmolviewer_17603786559316165"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17603786559316165" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17603786559316165 = null;
# var warn = document.getElementById("3dmolwarning_17603786559316165");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17603786559316165 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17603786559316165"),{backgroundColor:"white"});
# viewer_17603786559316165.zoomTo();
# 	viewer_17603786559316165.addModel("1\n\n F    0.000000000000    0.000000000000    0.000000000000\n","xyz");
# 	viewer_17603786559316165.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17603786559316165.zoomTo();
# viewer_17603786559316165.render();
# });
# </script>

# %%
psi4.core.set_output_file(f'f_radical.log', False)

# %%
psi4.set_options({"reference" :"uhf", "guess":"gwh", "opt_coordinates": "both"})
energies['hf']['f'] = psi4.optimize('hf/aug-cc-pvdz')
# Out:
# Optimizer: Optimization complete!

# %%
psi4.set_options({"reference" :"uhf","guess":"gwh", "mp2_type":"conv", "opt_coordinates": "both"})
energies['mp2']['f'] = psi4.optimize('mp2/aug-cc-pvdz')
# Out:
# Optimizer: Optimization complete!
# /opt/CompChem/psi4conda-1.9.1/lib/python3.12/site-packages/optking/stepAlgorithms.py:841: RuntimeWarning: invalid value encountered in scalar divide
#   alpha += 2 * (self.params.intrafrag_trust * step_len - step_len**2) / deriv
# /opt/CompChem/psi4conda-1.9.1/lib/python3.12/site-packages/optking/stepAlgorithms.py:93: RuntimeWarning: invalid value encountered in divide
#   unit_dq = dq / dq_norm

# %%
energies['mp3']['f'] = psi4.energy('mp3/aug-cc-pvdz')

# %% [markdown]
# ### BDE
#
# Now that we performed all the calculations required, it is finally possible to compute the BDE for the reaction.

# %%
# calculate the BDE energies here and convert them to kcal/mol 
# You can use psi4.constants.hartree2kcalmol for the unit conversion

energies['hf']['bde']  = (energies['hf']['ch3']  + energies['hf']['f']  - energies['hf']['ch3f'])  * psi4.constants.hartree2kcalmol # 
energies['mp2']['bde'] = (energies['mp2']['ch3'] + energies['mp2']['f'] - energies['mp2']['ch3f']) * psi4.constants.hartree2kcalmol # 
energies['mp3']['bde'] = (energies['mp3']['ch3'] + energies['mp3']['f'] - energies['mp3']['ch3f']) * psi4.constants.hartree2kcalmol #

# %%
pd.DataFrame.from_dict(energies)
# Out:
#               hf         mp2         mp3
# ch3f -139.057552 -139.422653 -139.436919
# ch3   -39.565801  -39.700946  -39.720405
# f     -99.381098  -99.537740  -99.547730
# bde    69.435479  115.440741  105.913684

# %% [markdown]
# :::{admonition} Exercise 5
# :class: exercise
# Is the homolytic cleavage of the H$_3$C-F bond likely, based on the
#     BDE that you calculated? (Think of radical processes in general.)
# :::

# %% [markdown]
# :::{admonition} Exercise 6
# :class: exercise
# What is the trend in energies when moving from HF over MP2 to MP3 for your calculations? Does this series converge? Do you expect the same trend for higher order MPn methods? Why?
#
# *Hint*: You can check the convergence for MP2 and MP3 by running the code cell below.
# :::

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(10,3),constrained_layout = True)

ax1.plot([1,2,3],[energies['hf']['ch3f'],energies['mp2']['ch3f'],energies['mp3']['ch3f']],'o-')
ax1.set_xlabel('Method')
ax1.set_ylabel('Energy (kcal/mol)')
ax1.set_xticks([1, 2, 3])
ax1.set_xticklabels(['HF', 'MP2', 'MP3'])
ax1.set_title('CH$_3$F')

ax2.plot([1,2,3],[energies['hf']['ch3'],energies['mp2']['ch3'],energies['mp3']['ch3']],'o-')
ax2.set_xlabel('Method')
ax2.set_ylabel('Energy (kcal/mol)')
ax2.set_xticks([1, 2, 3])
ax2.set_xticklabels(['HF', 'MP2', 'MP3'])
ax2.set_title('CH$_3$')

ax3.plot([1,2,3],[energies['hf']['f'],energies['mp2']['f'],energies['mp3']['f']],'o-')
ax3.set_xlabel('Method')
ax3.set_ylabel('Energy (kcal/mol)')
ax3.set_xticks([1, 2, 3])
ax3.set_xticklabels(['HF', 'MP2', 'MP3'])
ax3.set_title('F')

plt.gcf().set_dpi(300)
plt.show()

# %% [markdown]
# :::{admonition} Exercise 7
# :class: exercise
# Comment on the accuracy of the HF approach for this system. Is the
#     error associated with HF or with MPn bigger, and why?
#     (*Hint*: Think in terms of the scale of the absolute energy of the
#     reaction, as well as of the different components of the system.)
# :::

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(12, 3), constrained_layout=True)

ax1.plot([1, 2, 3], [energies['hf']['ch3f'], energies['mp2']['ch3f'], energies['mp3']['ch3f']], 'o-')
ax1.set_xlabel('Method')
ax1.set_ylabel('Energy (kcal/mol)')
ax1.set_xticks([1, 2, 3])
ax1.set_xticklabels(['HF', 'MP2', 'MP3'])
ax1.set_title('CH$_3$F')

ax2.plot([1, 2, 3], [energies['hf']['ch3'], energies['mp2']['ch3'], energies['mp3']['ch3']], 'o-')
ax2.set_xlabel('Method')
ax2.set_ylabel('Energy (kcal/mol)')
ax2.set_xticks([1, 2, 3])
ax2.set_xticklabels(['HF', 'MP2', 'MP3'])
ax2.set_title('CH$_3$')

ax3.plot([1, 2, 3], [energies['hf']['f'], energies['mp2']['f'], energies['mp3']['f']], 'o-')
ax3.set_xlabel('Method')
ax3.set_ylabel('Energy (kcal/mol)')
ax3.set_xticks([1, 2, 3])
ax3.set_xticklabels(['HF', 'MP2', 'MP3'])
ax3.set_title('F')

ax4.plot([1, 2, 3], [energies['hf']['bde'], energies['mp2']['bde'], energies['mp3']['bde']], 'o-')
ax4.axhline(y=109.2, color='r', linestyle='--', label='Exp. 109.2 kcal/mol')
ax4.set_xlabel('Method')
ax4.set_ylabel('BDE (kcal/mol)')
ax4.set_xticks([1, 2, 3])
ax4.set_xticklabels(['HF', 'MP2', 'MP3'])
ax4.set_title('BDE')
ax4.legend()

plt.gcf().set_dpi(300)
plt.show()
